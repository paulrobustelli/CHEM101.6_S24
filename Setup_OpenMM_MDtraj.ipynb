# %% [markdown]
# <a href="https://colab.research.google.com/github/paulrobustelli/CHEM101.6_S24/blob/main/Setup_OpenMM_MDtraj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 23.11.0

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install pandas numpy matplotlib
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.11            |       hd590300_1         542 KB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     ca-certificates-2024.2.2   |       hbcca054_0         152 KB  conda-forge
# ...

# %%
# !conda install -c conda-forge openmm
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openmm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.8.0         |      h4ba93d1_13       682.5 MB  conda-forge
#     ocl-icd-2.3.2              |       hd590300_1         133 KB  conda-forge
#     ocl-icd-system-1.0.0       |                1           4 KB  conda-forge
#     openmm-8.1.1               |  py310h43b6314_1        11.1 MB  conda-forge
#     scipy-1.12.0               |  py310hb13e2d6_2        15.7 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
# !conda install -c conda-forge mdtraj
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mdtraj
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     blosc-1.21.5               |       h0f2a231_0          48 KB  conda-forge
#     c-blosc2-2.14.0            |       hb4ffafa_0         329 KB  conda-forge
#     hdf5-1.14.3                |nompi_h4f84152_100         3.7 MB  conda-forge
#     libaec-1.1.3               |       h59595ed_0          35 KB  conda-forge
# ...
